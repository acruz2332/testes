# %%
import pandas as pd

# %%
df_test = pd.read_csv('healthkathon_afterpreprocessing.csv')
df_test = df_test.sort_values(by='id', ascending=True)
df_test
# Out:
#           Unnamed: 0        id  id_peserta  dati2  typefaskes  usia  jenkel  \
# 3836911     11328419         1     4294260      1          25    34       0
# 8709704      4732811         2     1173029      1          25     9       1
# 11145743     3615269         3     6714367      1          25    37       0
# 10569794     3211011         4     1168460      1          25    44       1
# 9314296      5489306         5     1014590      1          25    15       1
# ...              ...       ...         ...    ...         ...   ...     ...
# 7166528       474584  11426953      980654    386           3    51       0
# 10073321     3379363  11426954     2176337    386           3    31       1
# 5225816      9920496  11426955     2228160    386           3    54       1
# 1162789      7941957  11426956     2192754    386           3    48       0
# 8128522      1405002  11426957     2212167    386           3    47       1
#
# ...

# %%
X_test = df_test.drop(columns=['Unnamed: 0', 'label'])
X_test
# Out:
#                 id  id_peserta  dati2  typefaskes  usia  jenkel  pisat  \
# 0          5205817     6069898     51           1    28       0    1.0
# 1           478976     5386227     46           2    11       0    4.0
# 2          1368497     6320192    112           2    48       0    1.0
# 3         11397717     5507444    364           2    30       1    3.0
# 4          7244025     3340328    120           2    41       1    1.0
# ...            ...         ...    ...         ...   ...     ...    ...
# 11401877   2096276     1630386    130          23    70       1    3.0
# 11401878   7525084     1630386    130           1    67       1    3.0
# 11401879   2092640     1630386    130          23    70       1    3.0
# 11401880   2075609     1630390    129          24    50       0    1.0
# 11401881    102794     8527876     12          25     0       1    4.0
#
#           jenispel  politujuan  diagfktp  ...  tgldatang_year  \
# ...

# %%
y_test = df_test['label']
y_test
# Out:
# 3836911     0
# 8709704     0
# 11145743    0
# 10569794    0
# 9314296     0
#            ..
# 7166528     0
# 10073321    0
# 5225816     0
# 1162789     0
# 8128522     0
# Name: label, Length: 11401882, dtype: int64

# %%
df_train = pd.read_csv('trainset_randomoversampling2.csv')

# %%
df_train = pd.read_csv('trainset_SMOTE.csv')

# %%
df_train
# Out:
#          Unnamed: 0        id  id_peserta  dati2  typefaskes  usia  jenkel  \
# 0                 0   5205817     6069898     51           1    28       0
# 1                 1    478976     5386227     46           2    11       0
# 2                 2   1368497     6320192    112           2    48       0
# 3                 3  11397717     5507444    364           2    30       1
# 4                 4   7244025     3340328    120           2    41       1
# ...             ...       ...         ...    ...         ...   ...     ...
# 1886217     1886217   6038004     7147605    501           2    23       0
# 1886218     1886218   4356274     3396560    223          24    21       0
# 1886219     1886219    691550     5280237     69          17    41       0
# 1886220     1886220    140291     5336730     13           2    26       1
# 1886221     1886221   3397598     7514120    184          24     0       0
#
# ...

# %%
df_X = df_train.drop(columns=['label', 'Unnamed: 0'])
df_X
# Out:
#                id  id_peserta  dati2  typefaskes  usia  jenkel  pisat  \
# 0         5205817     6069898     51           1    28       0    1.0
# 1          478976     5386227     46           2    11       0    4.0
# 2         1368497     6320192    112           2    48       0    1.0
# 3        11397717     5507444    364           2    30       1    3.0
# 4         7244025     3340328    120           2    41       1    1.0
# ...           ...         ...    ...         ...   ...     ...    ...
# 1886217   6038004     7147605    501           2    23       0    4.0
# 1886218   4356274     3396560    223          24    21       0    4.0
# 1886219    691550     5280237     69          17    41       0    1.0
# 1886220    140291     5336730     13           2    26       1    3.0
# 1886221   3397598     7514120    184          24     0       0    4.0
#
#          jenispel  politujuan  diagfktp  ...  tgldatang_year  tgldatang_month  \
# ...

# %%
df_y = df_train['label']
df_y
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 1886217    1
# 1886218    1
# 1886219    1
# 1886220    1
# 1886221    1
# Name: label, Length: 1886222, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(df_X, df_y)
# Out:
# GaussianNB()

# %%
ypred_nb = nb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-10-8bea8f96abec> in <module>
# ----> 1 ypred_nb = nb.predict(X_test)
#
# ~\anaconda3\envs\gpu2\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      71             Predicted target values for X
#      72         """
# ---> 73         check_is_fitted(self)
#      74         X = self._check_X(X)
#      75         jll = self._joint_log_likelihood(X)
#
# ~\anaconda3\envs\gpu2\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\gpu2\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
# ...

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred_nb))
print(confusion_matrix(y_test, ypred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.47      0.64  11244993
#            1       0.02      0.58      0.03    156889
#
#     accuracy                           0.47  11401882
#    macro avg       0.50      0.53      0.33  11401882
# weighted avg       0.97      0.47      0.63  11401882
#
# [[5323457 5921536]
#  [  65357   91532]]

# %%
from sklearn.neighbors import KNeighborsClassifier

model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(df_X, df_y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
ypred_knn = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-71118b30db25> in <module>
# ----> 1 ypred_knn = model.predict(X_test)
#
# ~\anaconda3\envs\gpu2\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     195         X = check_array(X, accept_sparse='csr')
#     196
# --> 197         neigh_dist, neigh_ind = self.kneighbors(X)
#     198         classes_ = self.classes_
#     199         _y = self._y
#
# ~\anaconda3\envs\gpu2\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     706                 X, self._fit_X, reduce_func=reduce_func,
#     707                 metric=self.effective_metric_, n_jobs=n_jobs,
# --> 708                 **kwds))
#     709
#     710         elif self._fit_method in ['ball_tree', 'kd_tree']:
#
# ...

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred_knn))
print(confusion_matrix(y_test, ypred_knn))

# %%
from sklearn.ensemble import AdaBoostClassifier

ada=AdaBoostClassifier()

# %%
ada.fit(df_X, df_y)
# Out:
# AdaBoostClassifier()

# %%
ypred_ada = ada.predict(X_test)

# %%
print(classification_report(y_test, ypred_ada))
print(confusion_matrix(y_test, ypred_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93  11244993
#            1       0.06      0.58      0.11    156889
#
#     accuracy                           0.87  11401882
#    macro avg       0.53      0.73      0.52  11401882
# weighted avg       0.98      0.87      0.92  11401882
#
# [[9825786 1419207]
#  [  65782   91107]]

# %%
from xgboost import XGBClassifier
sgb = XGBClassifier()

# %%
sgb.fit(df_X, df_y)
# Out:
# C:\Users\akbar\anaconda3\envs\gpu2\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [06:40:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
# ...

# %%
ypred_sgb = sgb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred_sgb))
print(confusion_matrix(y_test, ypred_sgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94  11244993
#            1       0.09      0.80      0.16    156889
#
#     accuracy                           0.89  11401882
#    macro avg       0.54      0.85      0.55  11401882
# weighted avg       0.98      0.89      0.93  11401882
#
# [[10003226  1241767]
#  [   31264   125625]]

# %%
df_sub2 = pd.DataFrame()

# %%
df_sub2['id'] = df_test['id']

# %%
df_sub2['label'] = ypred_sgb

# %%
df_sub2
# Out:
#                 id  label
# 0          5205817      1
# 1           478976      0
# 2          1368497      1
# 3         11397717      1
# 4          7244025      0
# ...            ...    ...
# 11401877   2096276      0
# 11401878   7525084      1
# 11401879   2092640      0
# 11401880   2075609      0
# 11401881    102794      0
#
# [11401882 rows x 2 columns]

# %%
df_sub2.to_csv('answer2.csv',index=False)

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
dtc.fit(df_X, df_y)
# Out:
# DecisionTreeClassifier()

# %%
ypred_dtc = dtc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred_dtc))
print(confusion_matrix(y_test, ypred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.96  11244993
#            1       0.14      1.00      0.25    156889
#
#     accuracy                           0.92  11401882
#    macro avg       0.57      0.96      0.60  11401882
# weighted avg       0.99      0.92      0.95  11401882
#
# [[10279581   965412]
#  [       0   156889]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf.fit(df_X, df_y)
# Out:
# RandomForestClassifier()

# %%
ypred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred_rf))
print(confusion_matrix(y_test, ypred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98  11244993
#            1       0.01      0.02      0.01    156889
#
#     accuracy                           0.97  11401882
#    macro avg       0.50      0.50      0.50  11401882
# weighted avg       0.97      0.97      0.97  11401882
#
# [[11027803   217190]
#  [  154155     2734]]

# %%
df_sub1 = pd.DataFrame()

# %%
df_sub1['id'] = df_test['id']

# %%
df_sub1['label'] = ypred_rf

# %%
df_sub1 = df_sub1.sort_values(by='id', ascending=True)

# %%
df_sub1
# Out:
#                 id  label
# 3836911          1      0
# 8709704          2      0
# 11145743         3      0
# 10569794         4      0
# 9314296          5      0
# ...            ...    ...
# 7166528   11426953      0
# 10073321  11426954      0
# 5225816   11426955      0
# 1162789   11426956      0
# 8128522   11426957      0
#
# [11401882 rows x 2 columns]

# %%
df_sub1.to_csv('answer3.csv',index=False)

# %%
df_X.corr()
# Out:
#                        id  id_peserta     dati2  typefaskes      usia  \
# id               1.000000   -0.018882  0.525412   -0.434575  0.011783
# id_peserta      -0.018882    1.000000  0.026664    0.055071 -0.456208
# dati2            0.525412    0.026664  1.000000   -0.070803  0.018382
# typefaskes      -0.434575    0.055071 -0.070803    1.000000  0.014459
# usia             0.011783   -0.456208  0.018382    0.014459  1.000000
# jenkel          -0.027502   -0.049714  0.005920    0.027686  0.039588
# pisat           -0.000404    0.261442 -0.009803   -0.009134 -0.593942
# jenispel        -0.023820   -0.181172  0.022335    0.004935  0.194070
# politujuan      -0.040820   -0.207471  0.020197    0.028002  0.250172
# diagfktp         0.000245    0.149203  0.027540    0.000098 -0.183173
# biaya            0.036961    0.040762 -0.026531   -0.037339 -0.032990
# jenispulang      0.029939    0.005703 -0.003894   -0.040971  0.033168
# ...
